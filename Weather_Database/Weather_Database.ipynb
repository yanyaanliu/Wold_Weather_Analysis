# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 749

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f060e7f9e5287042692682aca0d3997f

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloud = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        descrip = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_cloud,
                          "Wind Speed": city_wind,
                          "Current Description":descrip })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bambous virieux
# Processing Record 2 of Set 1 | los llanos de aridane
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | takoradi
# Processing Record 5 of Set 1 | buala
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | souillac
# Processing Record 8 of Set 1 | ajdabiya
# Processing Record 9 of Set 1 | pascagoula
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | vohibinany
# Processing Record 13 of Set 1 | beyneu
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | talnakh
# Processing Record 16 of Set 1 | oyama
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | kaduna
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | torbay
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | cayenne
# Processing Record 24 of Set 1 | kavieng
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | hay river
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | vila franca do campo
# Processing Record 30 of Set 1 | georgetown
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | tiksi
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | arys
# Processing Record 42 of Set 1 | high level
# Processing Record 43 of Set 1 | severobaykalsk
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | saint-francois
# Processing Record 46 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | lufilufi
# Processing Record 49 of Set 1 | gravdal
# Processing Record 50 of Set 1 | kavaratti
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | teguldet
# Processing Record 3 of Set 2 | asosa
# Processing Record 4 of Set 2 | bronnoysund
# Processing Record 5 of Set 2 | havoysund
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | mariel
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 2 | pangai
# Processing Record 11 of Set 2 | akdepe
# Processing Record 12 of Set 2 | glazov
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | carahue
# Processing Record 15 of Set 2 | airai
# Processing Record 16 of Set 2 | sao francisco
# Processing Record 17 of Set 2 | gibara
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | tuatapere
# Processing Record 20 of Set 2 | goderich
# Processing Record 21 of Set 2 | timra
# Processing Record 22 of Set 2 | henties bay
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | saint-philippe
# Processing Record 25 of Set 2 | yar-sale
# Processing Record 26 of Set 2 | yemelyanovo
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | punta arenas
# Processing Record 29 of Set 2 | matara
# Processing Record 30 of Set 2 | vao
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | new norfolk
# Processing Record 34 of Set 2 | caxias
# Processing Record 35 of Set 2 | beringovskiy
# Processing Record 36 of Set 2 | severo-yeniseyskiy
# Processing Record 37 of Set 2 | bandrele
# Processing Record 38 of Set 2 | norman wells
# Processing Record 39 of Set 2 | denizli
# Processing Record 40 of Set 2 | oborniki
# Processing Record 41 of Set 2 | iqaluit
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | pio xii
# Processing Record 44 of Set 2 | rikitea
# Processing Record 45 of Set 2 | portland
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 2 | novyy urengoy
# Processing Record 49 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | whittlesea
# Processing Record 2 of Set 3 | saldanha
# Processing Record 3 of Set 3 | darab
# Processing Record 4 of Set 3 | esperance
# Processing Record 5 of Set 3 | upernavik
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | tuktoyaktuk
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | chubbuck
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 3 | cherskiy
# Processing Record 13 of Set 3 | chokurdakh
# Processing Record 14 of Set 3 | mosquera
# Processing Record 15 of Set 3 | umm jarr
# City not found. Skipping...
# Processing Record 16 of Set 3 | kyzyl-suu
# Processing Record 17 of Set 3 | sinnamary
# Processing Record 18 of Set 3 | palmer
# Processing Record 19 of Set 3 | mar del plata
# Processing Record 20 of Set 3 | lusambo
# Processing Record 21 of Set 3 | banmo
# City not found. Skipping...
# Processing Record 22 of Set 3 | victoria
# Processing Record 23 of Set 3 | meleuz
# Processing Record 24 of Set 3 | xining
# Processing Record 25 of Set 3 | bengkulu
# Processing Record 26 of Set 3 | sagarejo
# Processing Record 27 of Set 3 | shintomi
# Processing Record 28 of Set 3 | vanimo
# Processing Record 29 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 3 | biloela
# Processing Record 31 of Set 3 | nemuro
# Processing Record 32 of Set 3 | mahon
# Processing Record 33 of Set 3 | lavrentiya
# Processing Record 34 of Set 3 | nizwa
# Processing Record 35 of Set 3 | kautokeino
# Processing Record 36 of Set 3 | gilbues
# Processing Record 37 of Set 3 | flinders
# Processing Record 38 of Set 3 | locri
# Processing Record 39 of Set 3 | salinopolis
# Processing Record 40 of Set 3 | port hardy
# Processing Record 41 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 3 | dingle
# Processing Record 44 of Set 3 | saint george
# Processing Record 45 of Set 3 | mareeba
# Processing Record 46 of Set 3 | washington
# Processing Record 47 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 48 of Set 3 | vila
# Processing Record 49 of Set 3 | hoopstad
# Processing Record 50 of Set 3 | caravelas
# Processing Record 1 of Set 4 | nabire
# Processing Record 2 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 4 | thompson
# Processing Record 4 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 4 | sola
# Processing Record 6 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 4 | ludvika
# Processing Record 8 of Set 4 | paamiut
# Processing Record 9 of Set 4 | flin flon
# Processing Record 10 of Set 4 | shaki
# Processing Record 11 of Set 4 | pacific grove
# Processing Record 12 of Set 4 | meulaboh
# Processing Record 13 of Set 4 | bababe
# City not found. Skipping...
# Processing Record 14 of Set 4 | bandarbeyla
# Processing Record 15 of Set 4 | khash
# Processing Record 16 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 4 | tres arroyos
# Processing Record 18 of Set 4 | luderitz
# Processing Record 19 of Set 4 | tazovskiy
# Processing Record 20 of Set 4 | alcacer do sal
# Processing Record 21 of Set 4 | sahuaripa
# Processing Record 22 of Set 4 | morrope
# Processing Record 23 of Set 4 | hofn
# Processing Record 24 of Set 4 | mao
# Processing Record 25 of Set 4 | molo
# Processing Record 26 of Set 4 | roswell
# Processing Record 27 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 4 | jamestown
# Processing Record 29 of Set 4 | isabela
# Processing Record 30 of Set 4 | san patricio
# Processing Record 31 of Set 4 | surt
# Processing Record 32 of Set 4 | codrington
# Processing Record 33 of Set 4 | jutai
# Processing Record 34 of Set 4 | leningradskiy
# Processing Record 35 of Set 4 | sinop
# Processing Record 36 of Set 4 | praia da vitoria
# Processing Record 37 of Set 4 | aklavik
# Processing Record 38 of Set 4 | vanavara
# Processing Record 39 of Set 4 | nybro
# Processing Record 40 of Set 4 | saint-pierre
# Processing Record 41 of Set 4 | kruisfontein
# Processing Record 42 of Set 4 | ancud
# Processing Record 43 of Set 4 | baza
# Processing Record 44 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 4 | maningrida
# Processing Record 46 of Set 4 | ola
# Processing Record 47 of Set 4 | socorro
# Processing Record 48 of Set 4 | kamina
# Processing Record 49 of Set 4 | valparaiso
# Processing Record 50 of Set 4 | kampot
# Processing Record 1 of Set 5 | kapit
# Processing Record 2 of Set 5 | narsaq
# Processing Record 3 of Set 5 | inhambupe
# Processing Record 4 of Set 5 | shu
# Processing Record 5 of Set 5 | rybnoye
# Processing Record 6 of Set 5 | kaitangata
# Processing Record 7 of Set 5 | sitka
# Processing Record 8 of Set 5 | egvekinot
# Processing Record 9 of Set 5 | san estanislao
# Processing Record 10 of Set 5 | barcelos
# Processing Record 11 of Set 5 | oksfjord
# Processing Record 12 of Set 5 | monte patria
# Processing Record 13 of Set 5 | seoul
# Processing Record 14 of Set 5 | agua verde
# Processing Record 15 of Set 5 | xichang
# Processing Record 16 of Set 5 | lebu
# Processing Record 17 of Set 5 | merauke
# Processing Record 18 of Set 5 | axim
# Processing Record 19 of Set 5 | asekeyevo
# Processing Record 20 of Set 5 | caluquembe
# Processing Record 21 of Set 5 | huallanca
# Processing Record 22 of Set 5 | mehamn
# Processing Record 23 of Set 5 | warah
# Processing Record 24 of Set 5 | lerwick
# Processing Record 25 of Set 5 | kalininsk
# Processing Record 26 of Set 5 | deputatskiy
# Processing Record 27 of Set 5 | ca mau
# Processing Record 28 of Set 5 | atbasar
# Processing Record 29 of Set 5 | sampit
# Processing Record 30 of Set 5 | ferkessedougou
# Processing Record 31 of Set 5 | ossora
# Processing Record 32 of Set 5 | ponta do sol
# Processing Record 33 of Set 5 | gore
# Processing Record 34 of Set 5 | tori fatehpur
# Processing Record 35 of Set 5 | laukaa
# Processing Record 36 of Set 5 | hasaki
# Processing Record 37 of Set 5 | santa maria
# Processing Record 38 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 5 | tarakan
# Processing Record 40 of Set 5 | marrakesh
# Processing Record 41 of Set 5 | poum
# Processing Record 42 of Set 5 | mango
# Processing Record 43 of Set 5 | kurilsk
# Processing Record 44 of Set 5 | chuy
# Processing Record 45 of Set 5 | longyearbyen
# Processing Record 46 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 5 | horadiz
# Processing Record 48 of Set 5 | celestun
# Processing Record 49 of Set 5 | portsmouth
# Processing Record 50 of Set 5 | kolimvari
# City not found. Skipping...
# Processing Record 1 of Set 6 | waingapu
# Processing Record 2 of Set 6 | ostrovnoy
# Processing Record 3 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 6 | pisco
# Processing Record 5 of Set 6 | hobyo
# Processing Record 6 of Set 6 | bilibino
# Processing Record 7 of Set 6 | avera
# Processing Record 8 of Set 6 | edson
# Processing Record 9 of Set 6 | severo-kurilsk
# Processing Record 10 of Set 6 | road town
# Processing Record 11 of Set 6 | dawlatabad
# Processing Record 12 of Set 6 | yurimaguas
# Processing Record 13 of Set 6 | guaruja
# Processing Record 14 of Set 6 | sept-iles
# Processing Record 15 of Set 6 | riyadh
# Processing Record 16 of Set 6 | rakai
# Processing Record 17 of Set 6 | jalu
# Processing Record 18 of Set 6 | udachnyy
# Processing Record 19 of Set 6 | kawalu
# Processing Record 20 of Set 6 | yebaishou
# Processing Record 21 of Set 6 | januaria
# Processing Record 22 of Set 6 | devonport
# Processing Record 23 of Set 6 | richards bay
# Processing Record 24 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 6 | rongcheng
# Processing Record 26 of Set 6 | kenai
# Processing Record 27 of Set 6 | kununurra
# Processing Record 28 of Set 6 | hays
# Processing Record 29 of Set 6 | marzuq
# Processing Record 30 of Set 6 | chokwe
# Processing Record 31 of Set 6 | lagoa
# Processing Record 32 of Set 6 | katangli
# Processing Record 33 of Set 6 | otterup
# Processing Record 34 of Set 6 | elizabeth city
# Processing Record 35 of Set 6 | yakeshi
# Processing Record 36 of Set 6 | homer
# Processing Record 37 of Set 6 | kahului
# Processing Record 38 of Set 6 | taunggyi
# Processing Record 39 of Set 6 | roma
# Processing Record 40 of Set 6 | parker
# Processing Record 41 of Set 6 | fairbanks
# Processing Record 42 of Set 6 | carballo
# Processing Record 43 of Set 6 | rosetta
# Processing Record 44 of Set 6 | alta floresta
# Processing Record 45 of Set 6 | broome
# Processing Record 46 of Set 6 | nuuk
# Processing Record 47 of Set 6 | oriximina
# Processing Record 48 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 6 | gamba
# Processing Record 50 of Set 6 | port blair
# Processing Record 1 of Set 7 | antofagasta
# Processing Record 2 of Set 7 | cidreira
# Processing Record 3 of Set 7 | mbacke
# City not found. Skipping...
# Processing Record 4 of Set 7 | angoram
# Processing Record 5 of Set 7 | santo domingo
# Processing Record 6 of Set 7 | baiyin
# Processing Record 7 of Set 7 | taoudenni
# Processing Record 8 of Set 7 | bilma
# Processing Record 9 of Set 7 | sovetskiy
# Processing Record 10 of Set 7 | galeana
# Processing Record 11 of Set 7 | atar
# Processing Record 12 of Set 7 | geraldton
# Processing Record 13 of Set 7 | labrea
# Processing Record 14 of Set 7 | arlit
# Processing Record 15 of Set 7 | ormara
# Processing Record 16 of Set 7 | isangel
# Processing Record 17 of Set 7 | sami
# Processing Record 18 of Set 7 | siguiri
# Processing Record 19 of Set 7 | muros
# Processing Record 20 of Set 7 | roald
# Processing Record 21 of Set 7 | iralaya
# Processing Record 22 of Set 7 | rong kwang
# Processing Record 23 of Set 7 | itaueira
# Processing Record 24 of Set 7 | boden
# Processing Record 25 of Set 7 | uberherrn
# Processing Record 26 of Set 7 | morgaushi
# Processing Record 27 of Set 7 | stawell
# Processing Record 28 of Set 7 | moron
# Processing Record 29 of Set 7 | abha
# Processing Record 30 of Set 7 | derzhavinsk
# Processing Record 31 of Set 7 | leninsk
# Processing Record 32 of Set 7 | lasa
# Processing Record 33 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 7 | moussoro
# Processing Record 35 of Set 7 | west wendover
# Processing Record 36 of Set 7 | mahanoro
# Processing Record 37 of Set 7 | tabora
# Processing Record 38 of Set 7 | mount isa
# Processing Record 39 of Set 7 | adrar
# Processing Record 40 of Set 7 | pangkalanbuun
# Processing Record 41 of Set 7 | marawi
# Processing Record 42 of Set 7 | poya
# Processing Record 43 of Set 7 | emerald
# Processing Record 44 of Set 7 | alexandria
# Processing Record 45 of Set 7 | thurso
# Processing Record 46 of Set 7 | kloulklubed
# Processing Record 47 of Set 7 | san cristobal
# Processing Record 48 of Set 7 | remanso
# Processing Record 49 of Set 7 | lata
# Processing Record 50 of Set 7 | tautira
# Processing Record 1 of Set 8 | sergeyevka
# Processing Record 2 of Set 8 | olafsvik
# Processing Record 3 of Set 8 | bonthe
# Processing Record 4 of Set 8 | tekeli
# Processing Record 5 of Set 8 | fukue
# Processing Record 6 of Set 8 | port elizabeth
# Processing Record 7 of Set 8 | katsiveli
# City not found. Skipping...
# Processing Record 8 of Set 8 | te anau
# Processing Record 9 of Set 8 | smithers
# Processing Record 10 of Set 8 | bathsheba
# Processing Record 11 of Set 8 | athabasca
# Processing Record 12 of Set 8 | manakara
# Processing Record 13 of Set 8 | verkhniye kigi
# Processing Record 14 of Set 8 | hervey bay
# Processing Record 15 of Set 8 | maniitsoq
# Processing Record 16 of Set 8 | ilulissat
# Processing Record 17 of Set 8 | dourbali
# Processing Record 18 of Set 8 | palmas bellas
# Processing Record 19 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 8 | haradok
# Processing Record 21 of Set 8 | faanui
# Processing Record 22 of Set 8 | kutum
# Processing Record 23 of Set 8 | biak
# Processing Record 24 of Set 8 | uzhur
# Processing Record 25 of Set 8 | port macquarie
# Processing Record 26 of Set 8 | baker city
# Processing Record 27 of Set 8 | oranjemund
# Processing Record 28 of Set 8 | nakamura
# Processing Record 29 of Set 8 | lompoc
# Processing Record 30 of Set 8 | chivay
# Processing Record 31 of Set 8 | batagay-alyta
# Processing Record 32 of Set 8 | laguna
# Processing Record 33 of Set 8 | tura
# Processing Record 34 of Set 8 | dwarka
# Processing Record 35 of Set 8 | itarema
# Processing Record 36 of Set 8 | sao joao da barra
# Processing Record 37 of Set 8 | saraland
# Processing Record 38 of Set 8 | esso
# Processing Record 39 of Set 8 | long beach
# Processing Record 40 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 41 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 8 | baruun-urt
# Processing Record 43 of Set 8 | koygorodok
# Processing Record 44 of Set 8 | zhigansk
# Processing Record 45 of Set 8 | casin
# Processing Record 46 of Set 8 | burdur
# Processing Record 47 of Set 8 | saint anthony
# Processing Record 48 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 8 | kissidougou
# Processing Record 50 of Set 8 | thinadhoo
# Processing Record 1 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 9 | polunochnoye
# Processing Record 3 of Set 9 | skibotn
# Processing Record 4 of Set 9 | ranong
# Processing Record 5 of Set 9 | eyl
# Processing Record 6 of Set 9 | kent
# Processing Record 7 of Set 9 | maykain
# City not found. Skipping...
# Processing Record 8 of Set 9 | opuwo
# Processing Record 9 of Set 9 | camalu
# Processing Record 10 of Set 9 | akyab
# Processing Record 11 of Set 9 | samarai
# Processing Record 12 of Set 9 | jasper
# Processing Record 13 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 14 of Set 9 | nanakuli
# Processing Record 15 of Set 9 | taltal
# Processing Record 16 of Set 9 | tosya
# Processing Record 17 of Set 9 | svetlaya
# Processing Record 18 of Set 9 | college
# Processing Record 19 of Set 9 | ponta delgada
# Processing Record 20 of Set 9 | zaraza
# Processing Record 21 of Set 9 | faya
# Processing Record 22 of Set 9 | patharia
# Processing Record 23 of Set 9 | vieques
# Processing Record 24 of Set 9 | sokolo
# Processing Record 25 of Set 9 | jakar
# Processing Record 26 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 27 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 28 of Set 9 | bara
# Processing Record 29 of Set 9 | damietta
# Processing Record 30 of Set 9 | hutchinson
# Processing Record 31 of Set 9 | kajaani
# Processing Record 32 of Set 9 | pechenga
# Processing Record 33 of Set 9 | acin
# City not found. Skipping...
# Processing Record 34 of Set 9 | daru
# Processing Record 35 of Set 9 | forecariah
# Processing Record 36 of Set 9 | ladario
# Processing Record 37 of Set 9 | purificacion
# Processing Record 38 of Set 9 | tefe
# Processing Record 39 of Set 9 | okha
# Processing Record 40 of Set 9 | alofi
# Processing Record 41 of Set 9 | shar
# Processing Record 42 of Set 9 | horsham
# Processing Record 43 of Set 9 | adwa
# Processing Record 44 of Set 9 | tabou
# Processing Record 45 of Set 9 | nenjiang
# Processing Record 46 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 9 | guerrero negro
# Processing Record 48 of Set 9 | golden
# Processing Record 49 of Set 9 | cocal
# Processing Record 50 of Set 9 | sao filipe
# Processing Record 1 of Set 10 | cabo san lucas
# Processing Record 2 of Set 10 | fort nelson
# Processing Record 3 of Set 10 | ntungamo
# Processing Record 4 of Set 10 | zandvoort
# Processing Record 5 of Set 10 | kushiro
# Processing Record 6 of Set 10 | erzurum
# Processing Record 7 of Set 10 | mercedes
# Processing Record 8 of Set 10 | launceston
# Processing Record 9 of Set 10 | huilong
# Processing Record 10 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 10 | rudbar
# Processing Record 12 of Set 10 | padang
# Processing Record 13 of Set 10 | penzance
# Processing Record 14 of Set 10 | edwardsville
# Processing Record 15 of Set 10 | matamoros
# Processing Record 16 of Set 10 | berlevag
# Processing Record 17 of Set 10 | umm lajj
# Processing Record 18 of Set 10 | casteldaccia
# Processing Record 19 of Set 10 | nara
# Processing Record 20 of Set 10 | eureka
# Processing Record 21 of Set 10 | katsuura
# Processing Record 22 of Set 10 | bethel
# Processing Record 23 of Set 10 | dumas
# Processing Record 24 of Set 10 | san francisco
# Processing Record 25 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 10 | bereda
# Processing Record 27 of Set 10 | east migpulao
# Processing Record 28 of Set 10 | kaset sombun
# Processing Record 29 of Set 10 | margate
# Processing Record 30 of Set 10 | vestmannaeyjar
# Processing Record 31 of Set 10 | komsomolskiy
# Processing Record 32 of Set 10 | marsh harbour
# Processing Record 33 of Set 10 | namatanai
# Processing Record 34 of Set 10 | riaba
# City not found. Skipping...
# Processing Record 35 of Set 10 | tsuruoka
# Processing Record 36 of Set 10 | clyde river
# Processing Record 37 of Set 10 | port maria
# Processing Record 38 of Set 10 | ginir
# Processing Record 39 of Set 10 | zonguldak
# Processing Record 40 of Set 10 | kaniama
# Processing Record 41 of Set 10 | vigrestad
# Processing Record 42 of Set 10 | belyy yar
# Processing Record 43 of Set 10 | cozumel
# Processing Record 44 of Set 10 | rawson
# Processing Record 45 of Set 10 | nagorsk
# Processing Record 46 of Set 10 | kemijarvi
# Processing Record 47 of Set 10 | kiunga
# Processing Record 48 of Set 10 | dindori
# Processing Record 49 of Set 10 | kuryk
# Processing Record 50 of Set 10 | pavlodar
# Processing Record 1 of Set 11 | karpogory
# Processing Record 2 of Set 11 | nishihara
# Processing Record 3 of Set 11 | georgiyevskoye
# Processing Record 4 of Set 11 | boende
# Processing Record 5 of Set 11 | kieta
# Processing Record 6 of Set 11 | tual
# Processing Record 7 of Set 11 | esqueda
# Processing Record 8 of Set 11 | dutlwe
# Processing Record 9 of Set 11 | havre-saint-pierre
# Processing Record 10 of Set 11 | labuhan
# Processing Record 11 of Set 11 | sur
# Processing Record 12 of Set 11 | north branch
# Processing Record 13 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 15 of Set 11 | sao felix do xingu
# Processing Record 16 of Set 11 | okmulgee
# Processing Record 17 of Set 11 | nargana
# Processing Record 18 of Set 11 | hualmay
# Processing Record 19 of Set 11 | lethem
# Processing Record 20 of Set 11 | omsukchan
# Processing Record 21 of Set 11 | villanueva de la serena
# Processing Record 22 of Set 11 | dronten
# Processing Record 23 of Set 11 | pasighat
# Processing Record 24 of Set 11 | inhambane
# Processing Record 25 of Set 11 | katherine
# Processing Record 26 of Set 11 | parati
# Processing Record 27 of Set 11 | anadyr
# Processing Record 28 of Set 11 | moroni
# Processing Record 29 of Set 11 | ahipara
# Processing Record 30 of Set 11 | vyritsa
# Processing Record 31 of Set 11 | kristinehamn
# Processing Record 32 of Set 11 | virginia beach
# Processing Record 33 of Set 11 | westport
# Processing Record 34 of Set 11 | makakilo city
# Processing Record 35 of Set 11 | solnechnyy
# Processing Record 36 of Set 11 | billings
# Processing Record 37 of Set 11 | ingham
# Processing Record 38 of Set 11 | hornepayne
# Processing Record 39 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 40 of Set 11 | neuquen
# Processing Record 41 of Set 11 | san pedro
# Processing Record 42 of Set 11 | batagay
# Processing Record 43 of Set 11 | fortuna
# Processing Record 44 of Set 11 | kauhajoki
# Processing Record 45 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 46 of Set 11 | pomichna
# Processing Record 47 of Set 11 | manono
# Processing Record 48 of Set 11 | gulu
# Processing Record 49 of Set 11 | klaksvik
# Processing Record 50 of Set 11 | ixtapa
# Processing Record 1 of Set 12 | imelda
# Processing Record 2 of Set 12 | abu samrah
# Processing Record 3 of Set 12 | rocha
# Processing Record 4 of Set 12 | auki
# Processing Record 5 of Set 12 | bajil
# Processing Record 6 of Set 12 | toora-khem
# Processing Record 7 of Set 12 | mikuni
# Processing Record 8 of Set 12 | da nang
# Processing Record 9 of Set 12 | payakumbuh
# Processing Record 10 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 12 | turhal
# Processing Record 12 of Set 12 | capljina
# Processing Record 13 of Set 12 | bontang
# Processing Record 14 of Set 12 | genhe
# Processing Record 15 of Set 12 | kavos
# Processing Record 16 of Set 12 | maldonado
# Processing Record 17 of Set 12 | kaeo
# Processing Record 18 of Set 12 | asau
# Processing Record 19 of Set 12 | borovoy
# Processing Record 20 of Set 12 | pochutla
# Processing Record 21 of Set 12 | santa isabel
# Processing Record 22 of Set 12 | bowen
# Processing Record 23 of Set 12 | visnes
# Processing Record 24 of Set 12 | magdalena
# Processing Record 25 of Set 12 | pangody
# Processing Record 26 of Set 12 | kefamenanu
# Processing Record 27 of Set 12 | pontian kecil
# Processing Record 28 of Set 12 | carndonagh
# Processing Record 29 of Set 12 | masvingo
# Processing Record 30 of Set 12 | princeton
# Processing Record 31 of Set 12 | zaysan
# Processing Record 32 of Set 12 | am timan
# Processing Record 33 of Set 12 | soyo
# Processing Record 34 of Set 12 | yacuiba
# Processing Record 35 of Set 12 | lakes entrance
# Processing Record 36 of Set 12 | dieppe
# Processing Record 37 of Set 12 | wuwei
# Processing Record 38 of Set 12 | khandyga
# Processing Record 39 of Set 12 | nanortalik
# Processing Record 40 of Set 12 | whitehorse
# Processing Record 41 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 12 | seymchan
# Processing Record 43 of Set 12 | tucuman
# Processing Record 44 of Set 12 | oromocto
# Processing Record 45 of Set 12 | ambilobe
# Processing Record 46 of Set 12 | galesong
# Processing Record 47 of Set 12 | dmitriyevskoye
# Processing Record 48 of Set 12 | mayya
# Processing Record 49 of Set 12 | agrado
# Processing Record 50 of Set 12 | bam
# Processing Record 1 of Set 13 | konza
# Processing Record 2 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 13 | winnipeg
# Processing Record 4 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 13 | yabrud
# Processing Record 6 of Set 13 | quelimane
# Processing Record 7 of Set 13 | coihaique
# Processing Record 8 of Set 13 | choctaw
# Processing Record 9 of Set 13 | kholodnyy
# Processing Record 10 of Set 13 | hamilton
# Processing Record 11 of Set 13 | civitavecchia
# Processing Record 12 of Set 13 | buta
# Processing Record 13 of Set 13 | loyabad
# City not found. Skipping...
# Processing Record 14 of Set 13 | kenora
# Processing Record 15 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 16 of Set 13 | half moon bay
# Processing Record 17 of Set 13 | kismayo
# Processing Record 18 of Set 13 | moose factory
# Processing Record 19 of Set 13 | turan
# Processing Record 20 of Set 13 | yerbogachen
# Processing Record 21 of Set 13 | garden city
# Processing Record 22 of Set 13 | ayagoz
# Processing Record 23 of Set 13 | la ronge
# Processing Record 24 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 13 | burnie
# Processing Record 26 of Set 13 | hagi
# Processing Record 27 of Set 13 | santa cruz
# Processing Record 28 of Set 13 | coquimbo
# Processing Record 29 of Set 13 | sioux lookout
# Processing Record 30 of Set 13 | srednekolymsk
# Processing Record 31 of Set 13 | teya
# Processing Record 32 of Set 13 | marion
# Processing Record 33 of Set 13 | owando
# Processing Record 34 of Set 13 | lorengau
# Processing Record 35 of Set 13 | gaozhou
# Processing Record 36 of Set 13 | dunedin
# Processing Record 37 of Set 13 | zyryanka
# Processing Record 38 of Set 13 | kurikka
# Processing Record 39 of Set 13 | kousseri
# Processing Record 40 of Set 13 | sao joao do paraiso
# Processing Record 41 of Set 13 | atherton
# Processing Record 42 of Set 13 | lokosovo
# Processing Record 43 of Set 13 | araouane
# Processing Record 44 of Set 13 | evensk
# Processing Record 45 of Set 13 | vardo
# Processing Record 46 of Set 13 | gardan diwal
# City not found. Skipping...
# Processing Record 47 of Set 13 | jinchang
# Processing Record 48 of Set 13 | harper
# Processing Record 49 of Set 13 | owase
# Processing Record 50 of Set 13 | hirara
# Processing Record 1 of Set 14 | vostok
# Processing Record 2 of Set 14 | chalus
# Processing Record 3 of Set 14 | san jose
# Processing Record 4 of Set 14 | shache
# Processing Record 5 of Set 14 | conceicao do coite
# Processing Record 6 of Set 14 | summerville
# Processing Record 7 of Set 14 | turayf
# Processing Record 8 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 9 of Set 14 | harnosand
# Processing Record 10 of Set 14 | gainesville
# Processing Record 11 of Set 14 | puerto lopez
# Processing Record 12 of Set 14 | fuyang
# Processing Record 13 of Set 14 | keffi
# Processing Record 14 of Set 14 | lebork
# Processing Record 15 of Set 14 | waipawa
# Processing Record 16 of Set 14 | abalak
# Processing Record 17 of Set 14 | tongchuan
# Processing Record 18 of Set 14 | qasigiannguit
# Processing Record 19 of Set 14 | sayyan
# Processing Record 20 of Set 14 | agva
# City not found. Skipping...
# Processing Record 21 of Set 14 | foumbot
# Processing Record 22 of Set 14 | tromso
# Processing Record 23 of Set 14 | gushi
# Processing Record 24 of Set 14 | tripoli
# Processing Record 25 of Set 14 | amboasary
# Processing Record 26 of Set 14 | anloga
# Processing Record 27 of Set 14 | luganville
# Processing Record 28 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 29 of Set 14 | aras
# Processing Record 30 of Set 14 | nouakchott
# Processing Record 31 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 32 of Set 14 | olot
# Processing Record 33 of Set 14 | baherden
# Processing Record 34 of Set 14 | mandalay
# Processing Record 35 of Set 14 | jawala mukhi
# Processing Record 36 of Set 14 | xuanhua
# Processing Record 37 of Set 14 | leshukonskoye
# Processing Record 38 of Set 14 | kudahuvadhoo
# Processing Record 39 of Set 14 | coahuayana
# Processing Record 40 of Set 14 | honiara
# Processing Record 41 of Set 14 | lithgow
# Processing Record 42 of Set 14 | san juan
# Processing Record 43 of Set 14 | sabang
# Processing Record 44 of Set 14 | grindavik
# Processing Record 45 of Set 14 | kamennogorsk
# Processing Record 46 of Set 14 | luang prabang
# Processing Record 47 of Set 14 | acarau
# Processing Record 48 of Set 14 | sabha
# Processing Record 49 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 50 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 15 | pangnirtung
# Processing Record 2 of Set 15 | trondheim
# Processing Record 3 of Set 15 | kukes
# Processing Record 4 of Set 15 | kushmurun
# Processing Record 5 of Set 15 | fort abbas
# Processing Record 6 of Set 15 | ozernovskiy
# Processing Record 7 of Set 15 | kirakira
# Processing Record 8 of Set 15 | tevaitoa
# Processing Record 9 of Set 15 | hambantota
# Processing Record 10 of Set 15 | luanda
# Processing Record 11 of Set 15 | mandera
# Processing Record 12 of Set 15 | sangar
# Processing Record 13 of Set 15 | haines junction
# Processing Record 14 of Set 15 | pimenta bueno
# Processing Record 15 of Set 15 | gavle
# Processing Record 16 of Set 15 | nantai
# Processing Record 17 of Set 15 | hemsedal
# Processing Record 18 of Set 15 | rochelle
# Processing Record 19 of Set 15 | jiexiu
# Processing Record 20 of Set 15 | itoman
# Processing Record 21 of Set 15 | nizhniy kuranakh
# Processing Record 22 of Set 15 | markova
# Processing Record 23 of Set 15 | hadgaon
# Processing Record 24 of Set 15 | troitskoye
# Processing Record 25 of Set 15 | pancas
# Processing Record 26 of Set 15 | rudolfov
# Processing Record 27 of Set 15 | alekseyevsk
# Processing Record 28 of Set 15 | capitan bado
# Processing Record 29 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 30 of Set 15 | torrington
# Processing Record 31 of Set 15 | bolshoy lug
# Processing Record 32 of Set 15 | orcopampa
# Processing Record 33 of Set 15 | sarlat-la-caneda
# Processing Record 34 of Set 15 | amilpas
# City not found. Skipping...
# Processing Record 35 of Set 15 | san quintin
# Processing Record 36 of Set 15 | urumqi
# Processing Record 37 of Set 15 | parkersburg
# Processing Record 38 of Set 15 | novodolinskiy
# Processing Record 39 of Set 15 | odweyne
# Processing Record 40 of Set 15 | toulepleu
# City not found. Skipping...
# Processing Record 41 of Set 15 | nome
# Processing Record 42 of Set 15 | hami
# Processing Record 43 of Set 15 | sakakah
# Processing Record 44 of Set 15 | fianga
# City not found. Skipping...
# Processing Record 45 of Set 15 | gizo
# Processing Record 46 of Set 15 | huarmey
# Processing Record 47 of Set 15 | yulara
# Processing Record 48 of Set 15 | el balyana
# City not found. Skipping...
# Processing Record 49 of Set 15 | astipalaia
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 682

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Bambous Virieux      MU -20.3428   57.7575     71.85        68
# 1  Los Llanos De Aridane      ES  28.6585  -17.9182     69.55        83
# 2                Ushuaia      AR -54.8000  -68.3000     47.86        46
# 3               Takoradi      GH   4.8845   -1.7554     76.24        87
# 4                  Buala      SB  -8.1450  159.5921     79.32        82
# 5              Busselton      AU -33.6500  115.3333     48.49        75
# 6               Souillac      MU -20.5167   57.5167     71.98        68
# 7               Ajdabiya      LY  30.7554   20.2263     76.82        56
# 8             Pascagoula      US  30.3658  -88.5561     87.42        38
# 9             Butaritari      KI   3.0707  172.7902     81.36        78
#
#    Cloudiness  Wind Speed Current Description
# 0          75        9.22       broken clouds
# 1         100        5.75     overcast clouds
# 2           0        3.44           clear sky
# 3          24        5.70          few clouds
# 4          23        3.74          few clouds
# 5          10       12.88           clear sky
# 6          75        9.22       broken clouds
# 7           0       19.30           clear sky
# 8           0        6.91           clear sky
# 9          58       17.25          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order

new_city_data_df = city_data_df[new_column_order]

# Display sample data
new_city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Bambous Virieux      MU -20.3428   57.7575     71.85        68
# 1  Los Llanos De Aridane      ES  28.6585  -17.9182     69.55        83
# 2                Ushuaia      AR -54.8000  -68.3000     47.86        46
# 3               Takoradi      GH   4.8845   -1.7554     76.24        87
# 4                  Buala      SB  -8.1450  159.5921     79.32        82
# 5              Busselton      AU -33.6500  115.3333     48.49        75
# 6               Souillac      MU -20.5167   57.5167     71.98        68
# 7               Ajdabiya      LY  30.7554   20.2263     76.82        56
# 8             Pascagoula      US  30.3658  -88.5561     87.42        38
# 9             Butaritari      KI   3.0707  172.7902     81.36        78
#
#    Cloudiness  Wind Speed Current Description
# 0          75        9.22       broken clouds
# 1         100        5.75     overcast clouds
# 2           0        3.44           clear sky
# 3          24        5.70          few clouds
# 4          23        3.74          few clouds
# 5          10       12.88           clear sky
# 6          75        9.22       broken clouds
# 7           0       19.30           clear sky
# 8           0        6.91           clear sky
# 9          58       17.25          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
new_city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"


# Export the city_data DataFrame into a CSV file
new_city_data_df.to_csv(output_data_file, index_label="City_ID")
